# %%
mul_arr = [[None] * 10, [None] * 10]
# print(mul_arr)
string_1 = "giRtfel2t"
string_2 = "rightLeft2"
validity_check = ""
a = ""
b = ""
if len(string_1) <= 10 and len(string_2) <= 10:
    validity_check = "Valid Index for both String"
    print(validity_check)
else:
    print("Invalid Input Size")

if validity_check != "":
    for i in range(len(string_1)):
        if 65 <= ord(string_1[i]) <= 90:
            a = ("Capital letter is " + string_1[i] + " in string 1, Index: " + str(i))
            start_1 = i
            # print(a)
            break
    for j in range(len(string_2)):
        if 65 <= ord(string_2[j]) <= 90:
            b = ("Capital letter is " + string_2[j] + " in string 2, Index: " + str(j))
            start_2 = j
            # print(b)
            break

    if a == "" or b == "":
        print("Starting idx not found")
    else:
        print("Your strings are okay")

# string_1 = "giRtfel2th"
# string_2 = "rightLeft2"
if validity_check != "" and a != "" and b != "":
    size_row_1 = len(string_1)
    size_row_2 = len(string_2)
    # print(start_1, start_2)
    for x in range(len(string_1)):
        mul_arr[0][x] = string_1[x]
    for y in range(len(string_2)):
        mul_arr[1][y] = string_2[y]
    print(mul_arr)
    print(a)
    print(b)
    while True:
        k = input("Enter: ")
        if k == "Q" or k == "q":
            print("String 1 starting index:", start_1, "and Character:", mul_arr[0][start_1])
            print("String 2 starting index:", start_2, "and Character:", mul_arr[1][start_2])
            print(mul_arr)
            
            break
        elif k != "q" or k != "Q":

            temp = mul_arr[0][0]
            for y in range(size_row_1 - 1):
                mul_arr[0][y] = mul_arr[0][y + 1]
            mul_arr[0][len(string_1) - 1] = temp
        start_1 = start_1 - 1
        if start_1 < 0:
            start_1 = len(string_1) - 1
            # print(mul_arr)

        i = 0
        temp = mul_arr[1][len(string_2) - 1]
        for y in range(size_row_1 - 1):
            mul_arr[1][len(string_2) - 1 - i] = mul_arr[1][len(string_2) - 1 - i - 1]
            i += 1
        mul_arr[1][0] = temp
        start_2 = (start_2 + 1) % size_row_2

        print(mul_arr)
        # print(start_1)
        # print(start_2)
# Out:
# Valid Index for both String
# Your strings are okay
# [['g', 'i', 'R', 't', 'f', 'e', 'l', '2', 't', None], ['r', 'i', 'g', 'h', 't', 'L', 'e', 'f', 't', '2']]
# Capital letter is R in string 1, Index: 2
# Capital letter is L in string 2, Index: 5
# Enter: k
# [['i', 'R', 't', 'f', 'e', 'l', '2', 't', 'g', None], ['2', 'i', 'i', 'g', 'h', 't', 'L', 'e', 'f', 't']]
# Enter: q
# String 1 starting index: 1 and Character: R
# String 2 starting index: 6 and Character: L
# [['i', 'R', 't', 'f', 'e', 'l', '2', 't', 'g', None], ['2', 'i', 'i', 'g', 'h', 't', 'L', 'e', 'f', 't']]
